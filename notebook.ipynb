# %% [markdown]
# <link href='https://fonts.googleapis.com/css2?family=Lexend:wght@300;400;500;600;700&family=Lexend+Mono:wght@400;500&display=swap' rel='stylesheet'>
# <link rel='stylesheet' href='https://cdn.jsdelivr.net/npm/@tabler/icons-webfont@latest/dist/tabler-icons.min.css'>
#
# <style>
# /* ─── Global Reset & Font ─── */
# :root {
#   --kit-primary: #1a1a2e;
#   --kit-accent: #4f46e5;
#   --kit-accent-light: #ede9fe;
#   --kit-success: #059669;
#   --kit-success-light: #d1fae5;
#   --kit-warning: #d97706;
#   --kit-warning-light: #fef3c7;
#   --kit-danger: #dc2626;
#   --kit-danger-light: #fee2e2;
#   --kit-info: #0284c7;
#   --kit-info-light: #e0f2fe;
#   --kit-surface: #f8fafc;
#   --kit-border: #e2e8f0;
#   --kit-text: #1e293b;
#   --kit-muted: #64748b;
#   --kit-radius: 10px;
#   --kit-font: 'Lexend', sans-serif;
#   --kit-mono: 'Lexend Mono', monospace;
# }
#
# body, .jp-RenderedMarkdown, .jp-Cell {
#   font-family: var(--kit-font) !important;
# }
#
# .jp-RenderedMarkdown p,
# .jp-RenderedMarkdown li,
# .jp-RenderedMarkdown td {
#   font-family: var(--kit-font);
#   font-size: 14px;
#   line-height: 1.7;
#   color: var(--kit-text);
# }
#
# .jp-RenderedMarkdown code {
#   font-family: var(--kit-mono);
#   background: var(--kit-accent-light);
#   color: var(--kit-accent);
#   padding: 2px 7px;
#   border-radius: 5px;
#   font-size: 12.5px;
#   font-weight: 500;
# }
#
# /* ─── Step section headers ─── */
# .kit-step-header {
#   display: flex;
#   align-items: center;
#   gap: 14px;
#   padding: 18px 22px;
#   background: var(--kit-surface);
#   border: 1.5px solid var(--kit-border);
#   border-left: 5px solid var(--kit-accent);
#   border-radius: var(--kit-radius);
#   margin: 22px 0 14px;
# }
#
# .kit-step-icon {
#   width: 42px;
#   height: 42px;
#   border-radius: 10px;
#   background: var(--kit-accent);
#   display: flex;
#   align-items: center;
#   justify-content: center;
#   flex-shrink: 0;
#   color: #fff;
#   font-size: 20px;
# }
#
# .kit-step-content {
#   flex: 1;
# }
#
# .kit-step-label {
#   font-size: 10px;
#   font-weight: 600;
#   letter-spacing: 0.12em;
#   text-transform: uppercase;
#   color: var(--kit-muted);
#   margin: 0 0 2px;
# }
#
# .kit-step-title {
#   font-size: 17px;
#   font-weight: 600;
#   color: var(--kit-primary);
#   margin: 0 0 2px;
# }
#
# .kit-step-desc {
#   font-size: 13px;
#   color: var(--kit-muted);
#   margin: 0;
#   font-weight: 300;
# }
#
# .kit-step-badge {
#   font-size: 11px;
#   font-weight: 600;
#   padding: 4px 11px;
#   border-radius: 20px;
#   background: var(--kit-accent-light);
#   color: var(--kit-accent);
#   flex-shrink: 0;
#   letter-spacing: 0.04em;
#   font-family: var(--kit-mono);
# }
#
# /* ─── Tip box ─── */
# .kit-tip {
#   display: flex;
#   gap: 12px;
#   background: var(--kit-info-light);
#   border: 1px solid #bae6fd;
#   border-radius: var(--kit-radius);
#   padding: 14px 16px;
#   margin: 10px 0 0;
#   font-size: 13px;
#   color: #0c4a6e;
#   line-height: 1.65;
# }
#
# .kit-tip-icon {
#   font-size: 18px;
#   flex-shrink: 0;
#   color: var(--kit-info);
#   margin-top: 1px;
# }
#
# .kit-tip strong {
#   color: #0369a1;
#   font-weight: 600;
# }
#
# /* ─── Warning box ─── */
# .kit-warn {
#   display: flex;
#   gap: 12px;
#   background: var(--kit-warning-light);
#   border: 1px solid #fde68a;
#   border-radius: var(--kit-radius);
#   padding: 14px 16px;
#   margin: 10px 0 0;
#   font-size: 13px;
#   color: #78350f;
#   line-height: 1.65;
# }
#
# .kit-warn-icon {
#   font-size: 18px;
#   flex-shrink: 0;
#   color: var(--kit-warning);
#   margin-top: 1px;
# }
#
# /* ─── Badge row ─── */
# .kit-badge-row {
#   display: flex;
#   flex-wrap: wrap;
#   gap: 8px;
#   margin: 8px 0 4px;
# }
#
# .kit-badge {
#   display: inline-flex;
#   align-items: center;
#   gap: 5px;
#   font-size: 11.5px;
#   font-weight: 600;
#   padding: 4px 10px;
#   border-radius: 20px;
#   letter-spacing: 0.03em;
# }
#
# .kit-badge.online  { background: var(--kit-success-light); color: var(--kit-success); }
# .kit-badge.version { background: var(--kit-accent-light);  color: var(--kit-accent); }
# .kit-badge.mode    { background: #f0fdf4; color: #15803d; }
# .kit-badge.gpu     { background: #fdf4ff; color: #7e22ce; }
# .kit-badge.model   { background: #fff7ed; color: #c2410c; }
#
# /* ─── Hero banner ─── */
# .kit-hero {
#   position: relative;
#   padding: 36px 32px 30px;
#   background: var(--kit-primary);
#   border-radius: 14px;
#   overflow: hidden;
#   margin-bottom: 8px;
# }
#
# .kit-hero::before {
#   content: '';
#   position: absolute;
#   top: -60px; right: -60px;
#   width: 220px; height: 220px;
#   border-radius: 50%;
#   background: rgba(79,70,229,0.25);
# }
#
# .kit-hero::after {
#   content: '';
#   position: absolute;
#   bottom: -40px; left: 120px;
#   width: 160px; height: 160px;
#   border-radius: 50%;
#   background: rgba(79,70,229,0.12);
# }
#
# .kit-hero-eyebrow {
#   font-size: 10.5px;
#   font-weight: 600;
#   letter-spacing: 0.14em;
#   text-transform: uppercase;
#   color: #818cf8;
#   margin: 0 0 10px;
# }
#
# .kit-hero-title {
#   font-size: 30px;
#   font-weight: 700;
#   color: #fff;
#   margin: 0 0 6px;
#   letter-spacing: -0.02em;
#   line-height: 1.2;
# }
#
# .kit-hero-subtitle {
#   font-size: 14px;
#   color: #94a3b8;
#   margin: 0 0 20px;
#   font-weight: 300;
# }
#
# .kit-hero-desc {
#   font-size: 13.5px;
#   color: #cbd5e1;
#   margin: 0 0 22px;
#   max-width: 560px;
#   line-height: 1.65;
#   font-weight: 300;
# }
#
# /* ─── Pipeline tracker ─── */
# .kit-pipeline {
#   display: flex;
#   flex-wrap: wrap;
#   gap: 6px;
#   padding: 16px 20px;
#   background: rgba(255,255,255,0.06);
#   border: 1px solid rgba(255,255,255,0.1);
#   border-radius: 10px;
# }
#
# .kit-pipeline-step {
#   display: inline-flex;
#   align-items: center;
#   gap: 5px;
#   font-size: 11px;
#   font-weight: 500;
#   padding: 4px 10px;
#   border-radius: 20px;
#   background: rgba(255,255,255,0.08);
#   color: #94a3b8;
#   font-family: var(--kit-mono);
# }
#
# .kit-pipeline-step i { font-size: 12px; }
#
# /* ─── Divider ─── */
# .kit-divider {
#   display: flex;
#   align-items: center;
#   gap: 12px;
#   margin: 6px 0;
#   color: var(--kit-border);
#   font-size: 11px;
#   color: var(--kit-muted);
# }
# .kit-divider::before, .kit-divider::after {
#   content: '';
#   flex: 1;
#   height: 1px;
#   background: var(--kit-border);
# }
# </style>
#
# <div class='kit-hero'>
#   <p class='kit-hero-eyebrow'><i class='ti ti-cube'></i>&nbsp; Enterprise Machine Learning Suite</p>
#   <h1 class='kit-hero-title'>Flipova KitX</h1>
#   <p class='kit-hero-subtitle'>Modular ML Pipeline &mdash; v2.1.4</p>
#   <p class='kit-hero-desc'>Plateforme modulaire conçue pour l'excellence en Data Science. Ce notebook orchestre vos pipelines de données, du chargement multimodal à l'entraînement de modèles haute performance.</p>
#   <div class='kit-badge-row'>
#     <span class='kit-badge online'><i class='ti ti-point-filled'></i> Online</span>
#     <span class='kit-badge version'><i class='ti ti-tag'></i> v2.1.4</span>
#     <span class='kit-badge mode'><i class='ti ti-topology-star'></i> Modular Pipeline</span>
#     <span class='kit-badge gpu'><i class='ti ti-cpu'></i> cuML / RAPIDS</span>
#     <span class='kit-badge model'><i class='ti ti-bolt'></i> GPU Accelerated</span>
#   </div>
#   <div class='kit-pipeline'>
#     <span class='kit-pipeline-step'><i class='ti ti-package'></i> S00 Install</span>
#     <span class='kit-pipeline-step'><i class='ti ti-database'></i> S01 Load</span>
#     <span class='kit-pipeline-step'><i class='ti ti-briefcase'></i> S02 Context</span>
#     <span class='kit-pipeline-step'><i class='ti ti-chart-dots'></i> S03 EDA</span>
#     <span class='kit-pipeline-step'><i class='ti ti-tools'></i> S04 Features</span>
#     <span class='kit-pipeline-step'><i class='ti ti-sparkles'></i> S05 Clean</span>
#     <span class='kit-pipeline-step'><i class='ti ti-code'></i> S06 Encode</span>
#     <span class='kit-pipeline-step'><i class='ti ti-scale'></i> S07 Balance</span>
#     <span class='kit-pipeline-step'><i class='ti ti-brain'></i> S08 Model</span>
#     <span class='kit-pipeline-step'><i class='ti ti-chart-bar'></i> S09 Eval</span>
#     <span class='kit-pipeline-step'><i class='ti ti-adjustments'></i> S10 Optim</span>
#     <span class='kit-pipeline-step'><i class='ti ti-file-export'></i> S11 Predict</span>
#     <span class='kit-pipeline-step'><i class='ti ti-eye'></i> S12 XAI</span>
#     <span class='kit-pipeline-step'><i class='ti ti-report'></i> S13 Report</span>
#     <span class='kit-pipeline-step'><i class='ti ti-rocket'></i> S14 Deploy</span>
#   </div>
# </div>
#
# <p style='font-size:13px;color:#64748b;margin:10px 0 0;font-family:var(--kit-font);'>
#   <i class='ti ti-info-circle' style='vertical-align:-2px'></i>&nbsp;
#   <strong>Instructions :</strong> Exécutez la cellule d'initialisation, puis suivez les étapes <code>S00</code> &rarr; <code>S14</code> pour compléter votre flux de travail ML.
# </p>
#
# <a href='https://colab.research.google.com/github/dadflip/flipova-kitx/blob/main/notebook.ipynb' target='_parent'><img src='https://colab.research.google.com/assets/colab-badge.svg' alt='Open In Colab' style='margin-top:12px;margin-right:6px;'/></a>
# <a href='https://kaggle.com/kernels/welcome?src=https://github.com/dadflip/flipova-kitx/blob/main/notebook.ipynb' target='_parent'><img src='https://kaggle.com/static/images/open-in-kaggle.svg' alt='Open In Kaggle' style='margin-top:12px;margin-right:6px;'/></a>
# <a href='https://mybinder.org/v2/gh/dadflip/flipova-kitx/main?filepath=notebook.ipynb' target='_parent'><img src='https://mybinder.org/badge_logo.svg' alt='Launch Binder' style='margin-top:12px;'/></a>

# %%
# ── Cellule d'Installation & Mise à jour (Hard Reset) ─────────
# KAGGLE: Activez "Internet" dans les Settings (panneau de droite) sinon => erreur exit code 128.
# COLAB / BINDER: Ces options empêchent pip d'utiliser un vieux cache (wheel) et forcent la MAJ.
# 
# !pip install --upgrade --no-cache-dir --force-reinstall "git+https://github.com/dadflip/flipova-kitx.git" -q
print("Installation / Mise à jour terminée !")

# %%
# ── Cellule 0 : paquets de base ───────────────────────────────────────────────
import subprocess, sys
for pkg in ['pandas','numpy','matplotlib','seaborn','scikit-learn','scipy','ipywidgets']:
    subprocess.check_call([sys.executable,'-m','pip','install',pkg,'-q'],
                          stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
    print(f'  [OK] {pkg}')
print('Done.')

# %%
# ── Initialisation & Welcome ──────────────────────────────────────────────────
import sys, pathlib, traceback, urllib.request, os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import logging
logging.getLogger('absl').setLevel(logging.ERROR)
_root = str(pathlib.Path().absolute())
if _root not in sys.path:
    sys.path.insert(0, _root)

import ipywidgets as widgets
from IPython.display import display, HTML
from ml_pipeline import load_config, PipelineState, styles

styles.apply_globals()
state = PipelineState()

import ml_pipeline
config_path = pathlib.Path(ml_pipeline.__file__).parent / "default.toml"
state.config = load_config(str(config_path))

# Display Stylized Markdown Header
version = state.config.get("meta",{}).get("version","v2.1.4")
author = state.config.get("meta",{}).get("author","Flipova Designer")

from IPython.display import Markdown
display(Markdown(f"""
### Flipova Engine {version}
---
**Operator:** `{author}` | **Processing:** `GPU Accelerated` | **Status:** `Active` 
---
"""))

def _show(obj):
    """Affiche obj.ui avec diagnostic d'erreur."""
    if not hasattr(obj, 'ui'):
        print('[ERROR] pas de .ui sur', type(obj).__name__)
        return
    display(obj.ui)

# %% [markdown]
# <div class='kit-step-header'>
#   <div class='kit-step-icon'><i class='ti ti-package'></i></div>
#   <div class='kit-step-content'>
#     <p class='kit-step-label'>Etape 00</p>
#     <p class='kit-step-title'>Installation des packages</p>
#     <p class='kit-step-desc'>Préparation de l'environnement technique &mdash; installation des bibliothèques requises.</p>
#   </div>
#   <span class='kit-step-badge'>S00</span>
# </div>
#
# <div class='kit-warn'>
#   <i class='ti ti-alert-triangle kit-warn-icon'></i>
#   <div>
#     <strong>Note sur les avertissements TensorFlow / CUDA :</strong> Lors de l'installation, des messages du type <code>Unable to register cuDNN factory</code> ou <code>computation placer already registered</code> peuvent apparaître. Ces avertissements C++ sans gravité proviennent d'une double détection GPU dans l'environnement Colab/Kaggle et n'impactent pas le fonctionnement.
#   </div>
# </div>

# %%
# ── S00 — Installation des packages ──────────────────────────────────────────
try:
    from ml_pipeline.steps.s00_install import InstallerUI
    s00 = InstallerUI(state)
    display(s00.ui)
except Exception:
    traceback.print_exc()

# %% [markdown]
# <div class='kit-step-header'>
#   <div class='kit-step-icon'><i class='ti ti-database-import'></i></div>
#   <div class='kit-step-content'>
#     <p class='kit-step-label'>Etape 01</p>
#     <p class='kit-step-title'>Chargement des données</p>
#     <p class='kit-step-desc'>Importation des fichiers sources pour alimenter le pipeline de traitement.</p>
#   </div>
#   <span class='kit-step-badge'>S01</span>
# </div>
#
# <div class='kit-tip'>
#   <i class='ti ti-bulb kit-tip-icon'></i>
#   <div>
#     <strong>Astuce sur <code>Stratify Col</code> :</strong> Si vous utilisez le chargement avec <code>Auto-split</code>, l'option <strong>Stratify Col</strong> permet de conserver la proportion de chaque classe entre le Train, Validation et Test &mdash; évitant ainsi tout fort déséquilibre.
#   </div>
# </div>

# %%
# ── S01 — Chargement des données ──────────────────────────────────────────────
try:
    from ml_pipeline.steps.s01_loading import DataLoaderUI
    s01 = DataLoaderUI(state)
    display(s01.ui)
except Exception:
    traceback.print_exc()

# %% [markdown]
# <div class='kit-step-header'>
#   <div class='kit-step-icon'><i class='ti ti-briefcase'></i></div>
#   <div class='kit-step-content'>
#     <p class='kit-step-label'>Etape 02</p>
#     <p class='kit-step-title'>Contexte metier &amp; domaine ML</p>
#     <p class='kit-step-desc'>Definition des objectifs du projet et des domaines d'application pour orienter les analyses.</p>
#   </div>
#   <span class='kit-step-badge'>S02</span>
# </div>

# %%
# ── S02 — Contexte métier & domaine ML ───────────────────────────────────────
try:
    from ml_pipeline.steps.s02_domains import BusinessEditorUI
    s02 = BusinessEditorUI(state)
    display(s02.ui)
except Exception:
    traceback.print_exc()

# %% [markdown]
# <div class='kit-step-header'>
#   <div class='kit-step-icon'><i class='ti ti-chart-dots-3'></i></div>
#   <div class='kit-step-content'>
#     <p class='kit-step-label'>Etape 03</p>
#     <p class='kit-step-title'>EDA &mdash; Analyse exploratoire</p>
#     <p class='kit-step-desc'>Visualisation et comprehension approfondie de la structure et de la qualite des donnees.</p>
#   </div>
#   <span class='kit-step-badge'>S03</span>
# </div>

# %%
# ── S03 — EDA ─────────────────────────────────────────────────────────────────
try:
    from ml_pipeline.steps.s03_eda import UltimateEDA
    if not hasattr(state, 'eda_dashboard'):
        state.eda_dashboard = []
    s03 = UltimateEDA(state)
    display(s03.ui)
except Exception:
    traceback.print_exc()

# %% [markdown]
# <div class='kit-step-header'>
#   <div class='kit-step-icon'><i class='ti ti-tools'></i></div>
#   <div class='kit-step-content'>
#     <p class='kit-step-label'>Etape 04</p>
#     <p class='kit-step-title'>Feature Engineering</p>
#     <p class='kit-step-desc'>Creation de nouvelles variables et transformations mathematiques pour enrichir le dataset.</p>
#   </div>
#   <span class='kit-step-badge'>S04</span>
# </div>

# %%
# ── S04 — Feature Engineering ─────────────────────────────────────────────────
try:
    from ml_pipeline.steps.s04_feature_eng import FeatureEngUI
    s04 = FeatureEngUI(state)
    display(s04.ui)
except Exception:
    traceback.print_exc()

# %% [markdown]
# <div class='kit-step-header'>
#   <div class='kit-step-icon'><i class='ti ti-sparkles'></i></div>
#   <div class='kit-step-content'>
#     <p class='kit-step-label'>Etape 05</p>
#     <p class='kit-step-title'>Nettoyage des donnees</p>
#     <p class='kit-step-desc'>Traitement des valeurs manquantes et standardisation des formats pour garantir l'integrite des donnees.</p>
#   </div>
#   <span class='kit-step-badge'>S05</span>
# </div>

# %%
# ── S05 — Nettoyage des données ───────────────────────────────────────────────
try:
    from ml_pipeline.steps.s05_cleaning import AdvancedCleaner
    s05 = AdvancedCleaner(state)
    display(s05.ui)
except Exception:
    traceback.print_exc()

# %% [markdown]
# <div class='kit-step-header'>
#   <div class='kit-step-icon'><i class='ti ti-transform'></i></div>
#   <div class='kit-step-content'>
#     <p class='kit-step-label'>Etape 06</p>
#     <p class='kit-step-title'>Encodage &amp; Outliers</p>
#     <p class='kit-step-desc'>Encodage des variables categorielles et gestion des valeurs aberrantes pour preparer la modelisation.</p>
#   </div>
#   <span class='kit-step-badge'>S06</span>
# </div>

# %%
# ── S06 — Encodage & Outliers ─────────────────────────────────────────────────
try:
    from ml_pipeline.steps.s06_encoding import UltimateEncoder
    s06 = UltimateEncoder(state)
    display(s06.ui)
except Exception:
    traceback.print_exc()

# %% [markdown]
# <div class='kit-step-header'>
#   <div class='kit-step-icon'><i class='ti ti-scale'></i></div>
#   <div class='kit-step-content'>
#     <p class='kit-step-label'>Etape 07</p>
#     <p class='kit-step-title'>Dataset Balancing &mdash; Split &amp; Equilibrage</p>
#     <p class='kit-step-desc'>Equilibrage des classes si necessaire et division des donnees en sous-ensembles d'entrainement et de test.</p>
#   </div>
#   <span class='kit-step-badge'>S07</span>
# </div>
#
# <div class='kit-tip'>
#   <i class='ti ti-bulb kit-tip-icon'></i>
#   <div>
#     <strong>Qu'est-ce que <code>Stratify Col</code> ?</strong> Lorsqu'on divise un dataset, ce parametre force la division a conserver exactement la meme distribution de categories que dans le dataset d'origine pour la colonne choisie (en general, la variable cible). Cela evite qu'une classe minoritaire soit sous-representee dans le set de validation/test.
#   </div>
# </div>

# %%
# ── S07 — Dataset Balancing ───────────────────────────────────────────────────
try:
    from ml_pipeline.steps.s07_balancing import SplitBalancingUI
    s07 = SplitBalancingUI(state)
    display(s07.ui)
except Exception:
    traceback.print_exc()

# %% [markdown]
# <div class='kit-step-header'>
#   <div class='kit-step-icon'><i class='ti ti-brain'></i></div>
#   <div class='kit-step-content'>
#     <p class='kit-step-label'>Etape 08</p>
#     <p class='kit-step-title'>Modelisation</p>
#     <p class='kit-step-desc'>Entrainement des modeles d'apprentissage automatique selectionnes sur le dataset prepare.</p>
#   </div>
#   <span class='kit-step-badge'>S08</span>
# </div>

# %%
# ── S08 — Modélisation ────────────────────────────────────────────────────────
try:
    from ml_pipeline.steps.s08_modeling import ModelingUI
    s08 = ModelingUI(state)
    display(s08.ui)
except Exception:
    traceback.print_exc()

# %% [markdown]
# <div class='kit-step-header'>
#   <div class='kit-step-icon'><i class='ti ti-chart-bar'></i></div>
#   <div class='kit-step-content'>
#     <p class='kit-step-label'>Etape 09</p>
#     <p class='kit-step-title'>Evaluation &amp; Metriques</p>
#     <p class='kit-step-desc'>Analyse de la performance des modeles via des indicateurs de precision, rappel et autres metriques cles.</p>
#   </div>
#   <span class='kit-step-badge'>S09</span>
# </div>

# %%
# ── S09 — Évaluation & Métriques ─────────────────────────────────────────────
try:
    from ml_pipeline.steps.s09_metrics import EvaluationUI
    s09 = EvaluationUI(state)
    display(s09.ui)
except Exception:
    traceback.print_exc()

# %% [markdown]
# <div class='kit-step-header'>
#   <div class='kit-step-icon'><i class='ti ti-adjustments-horizontal'></i></div>
#   <div class='kit-step-content'>
#     <p class='kit-step-label'>Etape 10</p>
#     <p class='kit-step-title'>Optimisation des hyperparametres</p>
#     <p class='kit-step-desc'>Recherche automatique des meilleurs reglages pour maximiser la precision des modeles.</p>
#   </div>
#   <span class='kit-step-badge'>S10</span>
# </div>

# %%
# ── S10 — Optimisation des hyperparamètres ────────────────────────────────────
try:
    from ml_pipeline.steps.s10_optimization import OptimizationUI
    s10 = OptimizationUI(state)
    display(s10.ui)
except Exception:
    traceback.print_exc()

# %% [markdown]
# <div class='kit-step-header'>
#   <div class='kit-step-icon'><i class='ti ti-file-export'></i></div>
#   <div class='kit-step-content'>
#     <p class='kit-step-label'>Etape 11</p>
#     <p class='kit-step-title'>Predictions &amp; Export CSV</p>
#     <p class='kit-step-desc'>Generation de predictions sur de nouvelles donnees et export des resultats pour un usage externe.</p>
#   </div>
#   <span class='kit-step-badge'>S11</span>
# </div>

# %%
# ── S11 — Prédictions & Export CSV ───────────────────────────────────────────
try:
    from ml_pipeline.steps.s11_predictions import PredictionsUI
    s11 = PredictionsUI(state)
    display(s11.ui)
except Exception:
    traceback.print_exc()

# %% [markdown]
# <div class='kit-step-header'>
#   <div class='kit-step-icon'><i class='ti ti-eye-search'></i></div>
#   <div class='kit-step-content'>
#     <p class='kit-step-label'>Etape 12</p>
#     <p class='kit-step-title'>Sandbox &amp; Explicabilite (SHAP / LIME)</p>
#     <p class='kit-step-desc'>Interface interactive pour tester le modele et comprendre l'impact des variables sur les decisions (XAI).</p>
#   </div>
#   <span class='kit-step-badge'>S12</span>
# </div>

# %%
# ── S12 — Sandbox & Explicabilité (SHAP) ───────────────────────────────────
try:
    from ml_pipeline.steps.s12_sandbox import run as run_sandbox
    display(run_sandbox(state))
except Exception:
    import traceback
    traceback.print_exc()

# %% [markdown]
# <div class='kit-step-header'>
#   <div class='kit-step-icon'><i class='ti ti-report-analytics'></i></div>
#   <div class='kit-step-content'>
#     <p class='kit-step-label'>Etape 13</p>
#     <p class='kit-step-title'>Rapport &amp; Export artefacts</p>
#     <p class='kit-step-desc'>Generation d'un rapport de synthese final et export des artefacts du modele entraine.</p>
#   </div>
#   <span class='kit-step-badge'>S13</span>
# </div>

# %%
# ── S13 — Rapport & Export artefacts ─────────────────────────────────────────
try:
    from ml_pipeline.steps.s13_export import ReportGenerator
    s13 = ReportGenerator(state)
    display(s13.ui)
except Exception:
    traceback.print_exc()

# %% [markdown]
# <div class='kit-step-header'>
#   <div class='kit-step-icon' style='background:#059669'><i class='ti ti-rocket'></i></div>
#   <div class='kit-step-content'>
#     <p class='kit-step-label'>Etape 14</p>
#     <p class='kit-step-title'>Packaging, API &amp; Deploiement</p>
#     <p class='kit-step-desc'>Creation d'un package complet avec API FastAPI et Dockerfile pour une mise en production rapide.</p>
#   </div>
#   <span class='kit-step-badge' style='background:#d1fae5;color:#059669'>S14</span>
# </div>

# %%
# ── S14 — Packaging API & Déploiement ────────────────────────────────────────
try:
    from ml_pipeline.steps.s14_deploy import run as run_deploy
    display(run_deploy(state))
except Exception:
    import traceback
    traceback.print_exc()

# %% [markdown]
# <div class='kit-divider'><i class='ti ti-square-rounded-check'></i>&nbsp; Pipeline complet</div>
#
# <div style='padding:18px 22px;background:#f8fafc;border:1.5px solid #e2e8f0;border-radius:10px;margin-top:10px;display:flex;align-items:center;gap:14px;font-family:Lexend,sans-serif;'>
#   <i class='ti ti-clipboard-list' style='font-size:26px;color:#4f46e5;flex-shrink:0'></i>
#   <div>
#     <p style='margin:0 0 3px;font-size:15px;font-weight:600;color:#1e293b;'>Resume du pipeline</p>
#     <p style='margin:0;font-size:13px;color:#64748b;font-weight:300;'>Executez <code>state.summary()</code> ci-dessous pour afficher un recapitulatif complet de toutes les etapes executees, leurs configurations et leurs resultats.</p>
#   </div>
# </div>

# %%
# ── Résumé ────────────────────────────────────────────────────────────────────
state.summary()
