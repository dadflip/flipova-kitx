# %% [markdown]
# # 🚀 Flipova-KitX — ML Pipeline
#
# Un pipeline ML complet, modulaire et open-source pour l'analyse de données et le Machine Learning.
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/dadflip/flipova-kitx/blob/main/notebook.ipynb)
# [![Open In Kaggle](https://kaggle.com/static/images/open-in-kaggle.svg)](https://kaggle.com/kernels/welcome?src=https://github.com/dadflip/flipova-kitx/blob/main/notebook.ipynb)
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/dadflip/flipova-kitx/main?filepath=notebook.ipynb)
#
# ---
#
# ## 📌 Quick Start
#
# 1. Exécutez la cellule d'installation (S00)
# 2. Chargez vos données (S01)
# 3. Suivez les étapes S02 → S14
#
# > ⚠️ Redémarrez le kernel avant chaque nouvelle session.

# %% [markdown]
# # 📋 ML Pipeline — Aperçu des Étapes
#
# | Étape | Description |
# |---|---|
# | S00 | Installation |
# | S01 | Chargement des données |
# | S02 | Contexte métier |
# | S03 | EDA |
# | S04 | Feature Engineering |
# | S05 | Nettoyage |
# | S06 | Encodage |
# | S07 | Balancing |
# | S08 | Modélisation |
# | S09 | Évaluation |
# | S10 | Optimisation |
# | S11 | Prédictions |
# | S12 | Sandbox |
# | S13 | Rapport |
# | S14 | Déploiement |

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/dadflip/flipova-kitx/blob/main/notebook.ipynb)
# [![Open In Kaggle](https://kaggle.com/static/images/open-in-kaggle.svg)](https://kaggle.com/kernels/welcome?src=https://github.com/dadflip/flipova-kitx/blob/main/notebook.ipynb)
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/dadflip/flipova-kitx/main?filepath=notebook.ipynb)

# %%
# ── Installation Flipova-KitX ─────────────────────────────
# !pip install --upgrade --no-cache-dir --force-reinstall git+https://github.com/dadflip/flipova-kitx.git -q
print('✅ Installation terminée')

# %%
import subprocess
import sys

packages = [
    'pandas',
    'numpy',
    'matplotlib',
    'seaborn',
    'scikit-learn',
    'scipy',
    'ipywidgets'
]

for pkg in packages:
    subprocess.check_call([
        sys.executable,
        '-m',
        'pip',
        'install',
        pkg,
        '-q'
    ])
    print(f'✅ {pkg}')

# %%
import os
import sys
import pathlib
import traceback

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import logging
logging.getLogger('absl').setLevel(logging.ERROR)

ROOT = str(pathlib.Path().absolute())

if ROOT not in sys.path:
    sys.path.insert(0, ROOT)

import ipywidgets as widgets
from IPython.display import display

from ml_pipeline import load_config, PipelineState, styles

styles.apply_globals()

state = PipelineState()

import ml_pipeline

config_path = pathlib.Path(ml_pipeline.__file__).parent / 'default.toml'

state.config = load_config(str(config_path))

print('✅ Initialisation terminée')

# %% [markdown]
# ## 📦 S00 — Installation des packages

# %%
try:
    from ml_pipeline.steps.s00_install import InstallerUI

    s00 = InstallerUI(state)
    display(s00.ui)

except Exception:
    traceback.print_exc()

# %% [markdown]
# ## 📂 S01 — Chargement des données

# %%
try:
    from ml_pipeline.steps.s01_loading import DataLoaderUI

    s01 = DataLoaderUI(state)
    display(s01.ui)

except Exception:
    traceback.print_exc()

# %% [markdown]
# ## 🎯 S02 — Contexte métier

# %%
try:
    from ml_pipeline.steps.s02_domains import BusinessEditorUI

    s02 = BusinessEditorUI(state)
    display(s02.ui)

except Exception:
    traceback.print_exc()

# %% [markdown]
# ## ✅ Résumé final

# %%
from IPython.display import HTML

state.summary()

display(HTML('''
<div style="background-color:#d4edda;padding:15px;border-left:4px solid #28a745;">
    <h3>✅ Pipeline terminé</h3>
    <ul>
        <li>Exporter les artefacts</li>
        <li>Déployer l'API</li>
        <li>Partager les résultats</li>
    </ul>
</div>
'''))
